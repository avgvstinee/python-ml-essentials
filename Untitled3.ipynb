# %% [markdown]
# <a href="https://colab.research.google.com/github/avgvstinee/python-ml-essentials/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CONFIGURATIONS

# %%
CFG = {
    "num_classes": 100,
    "batch_size":  128,
    "epochs":      200,
    "lr":          0.001,
    "momentum":    0.9,
    "weight_decay":0.0001,
    "dropout_p":   0.2,
    "es_patience": 10,
}

# %% [markdown]
# ## Install and Libraries

# %%
# !pip install torch torchvision matplotlib -q
# !pip3 uninstall --yes torch torchaudio torchvision torchtext torchdata
# !pip3 install torch torchaudio torchvision torchtext torchdata
# Out:
# Found existing installation: torch 2.9.0+cpu
# Uninstalling torch-2.9.0+cpu:
#   Successfully uninstalled torch-2.9.0+cpu
# Found existing installation: torchaudio 2.9.0+cpu
# Uninstalling torchaudio-2.9.0+cpu:
#   Successfully uninstalled torchaudio-2.9.0+cpu
# Found existing installation: torchvision 0.24.0+cpu
# Uninstalling torchvision-0.24.0+cpu:
#   Successfully uninstalled torchvision-0.24.0+cpu
# WARNING: Skipping torchtext as it is not installed.
# WARNING: Skipping torchdata as it is not installed.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.6/915.6 MB 682.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 137.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 112.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 14.4 MB/s eta 0:00:00
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# 1. Device Setup for Mac
if torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
    print("Using MPS (Mac GPU)")
elif torch.cuda.is_available():
    DEVICE = torch.device("cuda")
    print("Using CUDA (NVIDIA GPU)")
else:
    DEVICE = torch.device("cpu")
    print("Using CPU (Warning: This will be slow)")
# Out:
# Using CPU (Warning: This will be slow)

# %% [markdown]
# # Data Augmentation

# %%
# Data Augmentation

transform_train = T.Compose([
    T.RandomCrop(32, padding=4),
    T.RandomHorizontalFlip(),
    T.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3),
    T.RandomRotation(15),
    T.ToTensor(),
    T.Normalize((0.5071, 0.4867, 0.4408),(0.2675, 0.2565, 0.2761))
])

transform_test = T.Compose([
    T.ToTensor(),
    T.Normalize((0.5071, 0.4867, 0.4408),(0.2675, 0.2565, 0.2761)
    ])


full_train_set = torchvision.datasets.CIFAR100(root='./data',
                                                   train=True,
                                                   download=True,
                                                   transform=transform_train
                                                   )
test_set = torchvision.datasets.CIFAR100(root='./data',
                                             train=False,
                                             download=True,
                                             transform=transform_test
                                             )

# Split 10% for validation
val_size = 5000
train_size = len(full_train_dataset) - val_size
train_dataset, val_set = random_split(full_train_dataset,
                                          [train_size, val_size]
                                          )



train_loader = DataLoader(train_set, batch_size=128,
                          shuffle=True,
                          num_workers=4,
                          pin_memory=True)
val_loader   = DataLoader(val_set,
                          batch_size=128,
                          shuffle=False,
                          num_workers=4,
                          pin_memory=True)

# %% [markdown]
# # RESIDUAL +BLOCK

# %% [markdown]
# #
# ######   x ──► Conv3x3 ──► BN ──► ReLU ──► Conv3x3 ──► BN ──► (+) ──► ReLU
# ######   │
# ######   └──────────────── downsampling ────────────────┘
# #

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_ch, out_ch, stride=1):
        super().__init__()
        self.main = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
        )
        # Skip connection projection: only when size or channels change
        self.skip_connection = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 1, stride=stride, bias=False),
            nn.BatchNorm2d(out_ch),
        ) if (stride != 1 or in_ch != out_ch) else nn.Identity()

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        return self.relu(self.main(x) + self.skip_connection(x))

# %% [markdown]
# # RESNET-18 ARCHITECTURE

# %% [markdown]
# #
# ###### Input (3,32,32)
# ######    │
# ######  Stem: Conv3x3-64, BN, ReLU          → (64,32,32)
# ######     │
# ######  Layer1: 2× BasicBlock(64→64,   s=1) → (64,32,32)
# ######   Layer2: 2× BasicBlock(64→128,  s=2) → (128,16,16)
# ######   Layer3: 2× BasicBlock(128→256, s=2) → (256,8,8)
# ######   Layer4: 2× BasicBlock(256→512, s=2) → (512,4,4)
# ######      │
# ######   GlobalAvgPool                        → (512,1,1)
# ######   Flatten                              → (512,)
# ######   Dropout(0.2)
# ######   Fully Connected 512→100                           → (100,)
# #

# %%
class ResNet18(nn.Module):
    def __init__(self, num_classes=100, dropout_p=0.2):
        super().__init__()
        # Stem — small 3×3 conv for CIFAR 32×32 (no maxpool)
        self.stem = nn.Sequential(
            nn.Conv2d(3, 64, 3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
        )
        self.layer1 = self._make_layer(64,  64,  2, stride=1)
        self.layer2 = self._make_layer(64,  128, 2, stride=2)
        self.layer3 = self._make_layer(128, 256, 2, stride=2)
        self.layer4 = self._make_layer(256, 512, 2, stride=2)
        self.pool    = nn.AdaptiveAvgPool2d(1)
        self.dropout = nn.Dropout(p=dropout_p)
        self.fc      = nn.Linear(512, num_classes)
        self._init_weights()

    def _make_layer(self, in_ch, out_ch, n_blocks, stride):
        layers = [BasicBlock(in_ch, out_ch, stride=stride)]
        for _ in range(1, n_blocks):
            layers.append(BasicBlock(out_ch, out_ch, stride=1))
        return nn.Sequential(*layers)

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode="fan_out", nonlinearity="relu")
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight); nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight); nn.init.zeros_(m.bias)

    def forward(self, x):
        x = self.stem(x)                  # (B,64,32,32)
        x = self.layer1(x)                # (B,64,32,32)
        x = self.layer2(x)                # (B,128,16,16)
        x = self.layer3(x)                # (B,256,8,8)
        x = self.layer4(x)                # (B,512,4,4)
        x = self.pool(x).flatten(1)       # (B,512)
        x = self.dropout(x)
        return self.fc(x)                 # (B,100)

# %% [markdown]
# # Early Stopping

# %%
class EarlyStopping:
    def __init__(self, patience=10, min_delta=1e-4):
        self.patience   = patience
        self.min_delta  = min_delta
        self.counter    = 0
        self.best_loss  = float("inf")
        self.best_epoch = 0
        self.best_wts   = None
        self.stop       = False

    def step(self, val_loss, epoch, model):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss  = val_loss
            self.best_epoch = epoch
            self.best_wts   = copy.deepcopy(model.state_dict())
            self.counter    = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                model.load_state_dict(self.best_wts)   # restore best weights
                self.stop = True

# %% [markdown]
# # ONE EPOCH

# %%
def run_epoch(model, loader, criterion, optimizer=None):
    training = optimizer is not None
    model.train() if training else model.eval()
    loss_sum, correct, total = 0.0, 0, 0

    ctx = torch.enable_grad() if training else torch.no_grad()
    with ctx:
        for imgs, labels in loader:
            imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
            logits = model(imgs)
            loss   = criterion(logits, labels)
            if training:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
            loss_sum += loss.item() * imgs.size(0)
            correct  += logits.argmax(1).eq(labels).sum().item()
            total    += imgs.size(0)

    return loss_sum / total, 100.0 * correct / total

# %% [markdown]
# # Validate the Model

# %%
def validate(model, loader, criterion):
    model.eval()
    val_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    return val_loss/len(loader), 100.*correct/total

# %% [markdown]
# # Training the Model

# %%
def train(model, train_loader, val_loader, cfg):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=cfg["lr"],
        momentum=cfg["momentum"],
        weight_decay=cfg["weight_decay"],
        nesterov=True,
    )
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=cfg["epochs"], eta_min=1e-6
    )
    es = EarlyStopping(patience=cfg["es_patience"])

    print(f"\n{'Ep':>4} | {'LR':>8} | {'Tr Loss':>8} {'Tr Acc':>7} | {'Va Loss':>8} {'Va Acc':>7} | {'Note'}")
    print("-" * 72)

    history = []
    for epoch in range(1, cfg["epochs"] + 1):
        training_loss, training_accuracy = run_epoch(model, train_loader, criterion, optimizer)
        validation_loss, validation_accuracy = run_epoch(model, val_loader,   criterion)
        scheduler.step()

        lr_now = optimizer.param_groups[0]["lr"]
        es.step(va_loss, epoch, model)
        note = "STOP" if es.stop else ("BEST" if es.counter == 0 else "")

        print(f"{epoch:>4} | {lr_now:>8.5f} | {tr_loss:>8.4f} {tr_acc:>6.1f}% | "
              f"{va_loss:>8.4f} {va_acc:>6.1f}% | {note}")

        history.append(dict(epoch=epoch, lr=lr_now,
                            train_loss=tr_loss, train_acc=tr_acc,
                            val_loss=va_loss,   val_acc=va_acc))
        if es.stop:
            print(f"\nEarly stop at epoch {epoch}. Best at epoch {es.best_epoch}.")
            break

    return history

# %% [markdown]
# # VISUALIZATIONS

# %%
import matplotlib.pyplot as plt

# Using the data from your best run (LR=0.001, WD=0.0001)
plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(history['training_acc'], label='Train Accuracy', color='blue')
plt.plot(history['validation_acc'], label='Val Accuracy', color='orange')
plt.title('Training and Validation Accuracy \nAccuracy: LR=0.001, WD=0.0001')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history['training_loss'], label='Training Loss', color='blue')
plt.plot(history['validation_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss \nLoss: LR=0.001, WD=0.0001')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
